# %%
import pandas as pd
import gensim
from gensim import corpora
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt

# Load the cleaned data
df = pd.read_csv("../data/cleaned_comments.csv")

# Tokenize the cleaned comments
tokenized = [text.split() for text in df["cleaned_comment"].dropna()]

# Create Dictionary and Corpus
dictionary = corpora.Dictionary(tokenized)
corpus = [dictionary.doc2bow(text) for text in tokenized]

# Train LDA Model (try 5 topics first)
lda_model = gensim.models.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=5,
    random_state=42,
    update_every=1,
    chunksize=100,
    passes=10,
    alpha='auto',
    per_word_topics=True
)

# Print top words per topic
for i, topic in lda_model.print_topics():
    print(f"\nTopic #{i}:")
    print(topic)

# Visualize Topics
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# Topic #0:
# 0.030*"vikram" + 0.014*"assemble" + 0.013*"vera" + 0.012*"bekku" + 0.010*"baakiyalakshmi" + 0.010*"intha" + 0.010*"level" + 0.009*"character" + 0.009*"mass" + 0.009*"karthik"
#
# Topic #1:
# 0.025*"hai" + 0.014*"ki" + 0.011*"fans" + 0.010*"ke" + 0.010*"ho" + 0.010*"se" + 0.009*"hi" + 0.009*"swag" + 0.009*"leo" + 0.008*"tha"
#
# Topic #2:
# 0.014*"story" + 0.012*"chiyaan" + 0.011*"entry" + 0.011*"modi" + 0.010*"ye" + 0.009*"interview" + 0.007*"mr" + 0.006*"thapar" + 0.006*"malik" + 0.006*"want"
#
# Topic #3:
# 0.029*"movie" + 0.028*"retro" + 0.021*"fan" + 0.019*"anna" + 0.018*"miss" + 0.017*"sir" + 0.014*"video" + 0.013*"nice" + 0.012*"la" + 0.011*"ott"
#
# Topic #4:
# 0.015*"da" + 0.014*"end" + 0.014*"la" + 0.012*"yo" + 0.012*"not" + 0.011*"ku" + 0.011*"like" + 0.011*"release" + 0.011*"serial" + 0.010*"theatre"
# /home/codespace/.local/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=27601) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/codespace/.local/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=27601) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/codespace/.local/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=27601) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el276011406362547159842627966329" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el276011406362547159842627966329_data = {"mdsDat": {"x": [-0.087487639793421, 0.21150228851618147, -0.029237422218451027, -0.07978214267914074, -0.014995083825168818], "y": [0.13570404719555418, 0.01694979570870235, -0.16952056408934363, -0.05532092167351231, 0.07218764285859942], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [28.171441032797663, 20.11377246168854, 19.11439374091635, 16.635814310284257, 15.96457845431319]}, "tinfo": {"Term": ["vikram", "retro", "movie", "hai", "fan", "anna", "miss", "sir", "ki", "la", "da", "end", "assemble", "vera", "video", "nice", "story", "yo", "bekku", "theatre", "not", "fans", "ku", "like", "ke", "chiyaan", "ott", "entry", "kerala", "release", "ki", "ke", "fans", "hi", "swag", "leo", "tha", "k", "ji", "girl", "h", "raha", "happy", "tu", "pls", "hai", "ap", "ne", "love", "janvi", "comment", "dono", "hain", "know", "gaya", "birthday", "liye", "bless", "di", "apne", "apki", "mere", "ho", "se", "god", "baby", "bhai", "kar", "vikram", "vera", "assemble", "bekku", "baakiyalakshmi", "level", "character", "mass", "karthik", "true", "gnanam", "good", "masterpiece", "subbaraj", "come", "nee", "ellarum", "act", "guy", "promo", "sindoor", "intha", "pal", "thank", "go", "operation", "attack", "hotel", "vanthu", "adichu", "malik", "satya", "selvi", "movie", "serial", "oru", "da", "end", "yo", "not", "ku", "like", "king", "badila", "cobra", "ida", "narayana", "pannirukalam", "addddddddddddddddddddfdddddddd", "kommala", "thalapathy", "sanjay", "super", "ae", "illaya", "nu", "honey", "jason", "lyca", "singh", "ithuku", "watch", "nepotism", "bro", "sundeep", "mom", "release", "la", "serial", "vijay", "theatre", "oru", "song", "retro", "fan", "anna", "miss", "sir", "video", "nice", "ott", "kerala", "bgm", "experience", "bunda", "vitutan", "clarity", "channel", "ka", "loop", "wait", "game", "help", "vote", "time", "real", "happen", "sargun", "stop", "te", "kill", "hu", "look", "movie", "india", "la", "theatre", "song", "main", "nimrat", "entry", "ye", "interview", "mr", "want", "person", "kt", "story", "reason", "chiyaan", "hay", "word", "msdhoni", "thala", "modi", "karenge", "right", "upload", "useless", "kyu", "son", "joker", "nehi", "life", "public", "yeh", "copyright", "ek", "villain", "ask", "thapar", "government", "desh", "nahi", "kr", "malik", "karan", "people", "congratulation", "nhi", "song", "kya"], "Freq": [32.0, 25.0, 32.0, 39.0, 19.0, 17.0, 16.0, 15.0, 21.0, 24.0, 15.0, 14.0, 15.0, 14.0, 12.0, 12.0, 13.0, 13.0, 12.0, 18.0, 12.0, 16.0, 12.0, 12.0, 16.0, 11.0, 10.0, 10.0, 9.0, 13.0, 21.064239676812615, 15.594674349193305, 16.253470921204368, 13.986167334137724, 13.670325694582564, 13.670325694582564, 12.237080495220415, 11.389582244810994, 11.653226416141772, 10.83717914060675, 9.049176203944025, 8.924082738897873, 8.507339943278502, 7.822954523329555, 7.750454757072688, 36.763406282242556, 7.462218570488357, 7.2517353332818795, 7.040049501553859, 6.8037535808973955, 6.560087076592421, 6.318098643486871, 6.061391982748581, 6.523820857642451, 5.7326627702846595, 5.910340549711979, 5.647992816983905, 4.971073215047316, 4.9701636226013965, 4.804423853009758, 5.687167507308521, 5.245549426338759, 15.579966548680693, 14.198968172578205, 6.740449144311613, 8.693855402156483, 7.2695392933314595, 6.063045028859697, 31.68634550438534, 14.009421049534767, 14.470718247146168, 12.274091631672425, 10.403227462584494, 10.195414326767526, 9.422523489494987, 9.331053588214882, 9.178147804504926, 7.849977024413212, 7.309021234980645, 7.346259269159774, 7.299908391339347, 7.299908391339347, 5.193912408119107, 4.945675390765378, 4.791413177576, 4.856910903715909, 4.534330830481232, 4.173528529998384, 4.098933594146412, 10.355944504792477, 3.6798239341841477, 3.688570993512847, 3.5328158641602414, 3.2937765603493774, 3.095989488167172, 2.92084456419791, 2.920690210166406, 2.9200531895894435, 6.527124758152998, 3.5183050962532296, 3.8275040150075923, 5.75721280479392, 4.709651201878586, 3. ...

# %%
import pickle

# Save model and data
with open("../models/lda_model.pkl", "wb") as f:
    pickle.dump(lda_model, f)
with open("../models/dictionary.pkl", "wb") as f:
    pickle.dump(dictionary, f)
with open("../models/corpus.pkl", "wb") as f:
    pickle.dump(corpus, f)
